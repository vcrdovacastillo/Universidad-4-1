# %%
import pandas as pd
import numpy as np
import math as mat

import matplotlib.pyplot as plt
# %matplotlib

# %%
df = pd.read_csv('p1_dataset_elpino_raw.csv', sep=';', na_values='-')
df
# Out:
#                              Diag 01 Principal (cod+des)  \
# 0                A41.8 - Otras septicemias especificadas
# 1                   U07.1 - COVID-19, virus identificado
# 2      K56.5 - Adherencias [bridas] intestinales con ...
# 3      K76.8 - Otras enfermedades especificadas del h...
# 4      T81.0 - Hemorragia y hematoma que complican un...
# ...                                                  ...
# 14556  E10.1 - Diabetes mellitus tipo 1 con cetoacidosis
# 14557  S09.9 - Traumatismo de la cabeza, no especificado
# 14558                                     K92.1 - Melena
# 14559                     E78.1 - Hipergliceridemia pura
# 14560  S06.51 - Hemorragia subdural traumática, con h...
#
#                             Diag 02 Secundario (cod+des)  \
# 0         B37.6 - Endocarditis debida a candida (I39.8*)
# 1                  J12.8 - Neumonía debida a otros virus
# 2                                  R57.2 - Shock séptico
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14561 entries, 0 to 14560
# Data columns (total 68 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Diag 01 Principal (cod+des)     14561 non-null  object
#  1   Diag 02 Secundario (cod+des)    13352 non-null  object
#  2   Diag 03 Secundario (cod+des)    11874 non-null  object
#  3   Diag 04 Secundario (cod+des)    10434 non-null  object
#  4   Diag 05 Secundario (cod+des)    9190 non-null   object
#  5   Diag 06 Secundario (cod+des)    8167 non-null   object
#  6   Diag 07 Secundario (cod+des)    7153 non-null   object
#  7   Diag 08 Secundario (cod+des)    5977 non-null   object
#  8   Diag 09 Secundario (cod+des)    4842 non-null   object
#  9   Diag 10 Secundario (cod+des)    3865 non-null   object
#  10  Diag 11 Secundario (cod+des)    2987 non-null   object
#  11  Diag 12 Secundario (cod+des)    2323 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Diag 01 Principal (cod+des)           0
# Diag 02 Secundario (cod+des)       1209
# Diag 03 Secundario (cod+des)       2687
# Diag 04 Secundario (cod+des)       4127
# Diag 05 Secundario (cod+des)       5371
#                                   ...
# Proced 29 Secundario (cod+des)    13379
# Proced 30 Secundario (cod+des)    13498
# Edad en años                          0
# Sexo (Desc)                           0
# GRD                                   0
# Length: 68, dtype: int64

# %%
numerical_features = ["Edad en años"]
categorical_features = ["Proced 01 Secundario (cod+des)", "Proced 02 Secundario (cod+des)", "Proced 03 Secundario (cod+des)", 
                        "Proced 04 Secundario (cod+des)", "Proced 05 Secundario (cod+des)", "Proced 06 Secundario (cod+des)", 
                        "Proced 07 Secundario (cod+des)", "Proced 08 Secundario (cod+des)", "Proced 09 Secundario (cod+des)", 
                        "Proced 10 Secundario (cod+des)", "Proced 11 Secundario (cod+des)", "Proced 12 Secundario (cod+des)", 
                        "Proced 13 Secundario (cod+des)", "Proced 14 Secundario (cod+des)", "Proced 15 Secundario (cod+des)",
                        "Proced 16 Secundario (cod+des)", "Proced 17 Secundario (cod+des)", "Proced 18 Secundario (cod+des)",
                        "Proced 19 Secundario (cod+des)", "Proced 20 Secundario (cod+des)", "Proced 21 Secundario (cod+des)",
                        "Proced 22 Secundario (cod+des)", "Proced 23 Secundario (cod+des)", "Proced 24 Secundario (cod+des)",
                        "Proced 25 Secundario (cod+des)", "Proced 26 Secundario (cod+des)", "Proced 27 Secundario (cod+des)",
                        "Proced 28 Secundario (cod+des)", "Proced 29 Secundario (cod+des)", "Proced 30 Secundario (cod+des)",
                        "Sexo (Desc)", "GRD"]

# %%
def desc_num_feature(numerical_features):
    feature_name = numerical_features
    fig, ax = pl
